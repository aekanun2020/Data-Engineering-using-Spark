# %%
dict_in_list = [{
  "name": "name1 surname1",
  "age": 25,
  "gender": "male"
},{
  "name": "name2 surname2",
  "age": 50,
  "gender": "female"
}]

# %%
spark.createDataFrame(dict_in_list).show()
# Out:
# +---+------+--------------+
# |age|gender|          name|
# +---+------+--------------+
# | 25|  male|name1 surname1|
# | 50|female|name2 surname2|
# +---+------+--------------+

# %%
spark.createDataFrame(dict_in_list)
# Out:
# DataFrame[age: bigint, gender: string, name: string]

# %%
raw_df = spark.createDataFrame(dict_in_list)

# %%
raw_df.show()
# Out:
# +---+------+--------------+
# |age|gender|          name|
# +---+------+--------------+
# | 25|  male|name1 surname1|
# | 50|female|name2 surname2|
# +---+------+--------------+

# %%
raw_df.select([x for x in raw_df.columns if 'ge' in x]).show()
# Out:
# +---+------+
# |age|gender|
# +---+------+
# | 25|  male|
# | 50|female|
# +---+------+
